# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
# %matplotlib inline
from patsy import dmatrices
from sklearn import cross_validation as cv
from sklearn import linear_model, datasets, metrics
import statsmodels.api as smf
from sklearn.cross_validation import KFold

pd.set_option('display.mpl_style', 'default')               # Produces pretty plots!
plt.rcParams['figure.figsize'] = (15, 15)
# Out:
# /Users/kpully/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Read in data

# %%
data = pd.read_csv('result.csv')
try:
    data = data.drop(['western', 'war', 'Unnamed: 0.1', 'noir', 'mystery', 'Unnamed: 0', 'crime', 
                      'adventure', 'animation', 'fantasy', 'musical', 'index',
                      'romance' ,'horror', 'scifi', 'id', 'dates', 'title.1'], axis=1)
except:
    pass
data['domestic gross'] = data['domestic gross'].str.replace('$', '').str.replace(',', '').astype(float)
data['production budget'] = data['production budget'].str.replace('$', '').str.replace(',', '').astype(float)
data.columns = (['action', 'children', 'comedy', 'date', 'docmentary', 'drama', 'thriller',
                'title', 'dgross', 'pbudget', 'wgross'])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-657072517b89> in <module>()
# ----> 1 data = pd.read_csv('result.csv')
#       2 try:
#       3     data = data.drop(['western', 'war', 'Unnamed: 0.1', 'noir', 'mystery', 'Unnamed: 0', 'crime',
#       4                       'adventure', 'animation', 'fantasy', 'musical', 'index',
#       5                       'romance' ,'horror', 'scifi', 'id', 'dates', 'title.1'], axis=1)
#
# ...

# %%
data.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-efa692752119> in <module>()
# ----> 1 data.describe()
#
# NameError: name 'data' is not defined

# %% [markdown]
# transformations

# %%
len(data)
# Out:
# 1663

# %%
data = data[data.dgross > 0]

# %%
len(data_)
# Out:
# 1637

# %%
data['log_budget']=np.log(data.pbudget)
data['log_gross']=np.log(data.dgross)
# Out:
# /Users/kpully/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/kpully/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
data.replace([np.inf, -np.inf], np.nan)
data.dropna(inplace=True)

# %%
data.describe()
# Out:
#             action     children       comedy   docmentary        drama  \
# count  1637.000000  1637.000000  1637.000000  1637.000000  1637.000000
# mean      0.149053     0.072694     0.302382     0.030544     0.430666
# std       0.356250     0.259713     0.459430     0.172130     0.495321
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           thriller        dgross       pbudget   log_budget    log_gross
# count  1637.000000  1.637000e+03  1.637000e+03  1637.000000  1637.000000
# mean      0.147831  8.766961e+07  7.293903e+07    17.956644    17.803334
# std       0.355041  8.731882e+07  4.589895e+07     0.517292     1.177312
# ...

# %%
# Lets take a look at our entire model
pd.tools.plotting.scatter_matrix(data[['pbudget', 'dgross']])
print ''

# %%
# Lets take a look at our entire model
pd.tools.plotting.scatter_matrix(data[['log_gross', 'pbudget', 'dgross', 'log_budget']])
print ''

# %%
y, X = dmatrices('dgross ~ pbudget + thriller + comedy + drama + docmentary', data=data, return_type='dataframe')

# %% [markdown]
# Regular regression (statsmodels)

# %%
model = smf.OLS(y, X)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 dgross   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     170.9
# Date:                Thu, 14 Jul 2016   Prob (F-statistic):          8.30e-147
# Time:                        17:23:21   Log-Likelihood:                -32441.
# No. Observations:                1664   AIC:                         6.489e+04
# Df Residuals:                    1658   BIC:                         6.493e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   9.899e+06   4.52e+06      2.193      0.028      1.04e+06  1.88e+07
# ...

# %% [markdown]
# Linear regression using sklearn

# %%
model = linear_model.LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(X, y) #not great
# Out:
# 0.34006741757404724

# %%
model.coef_
# Out:
# array([[  0.00000000e+00,   1.10268836e+00,  -2.52824531e+06,
#          -2.10674325e+06,  -7.08394746e+06,   1.59049695e+06]])

# %%
model.intercept_
# Out:
# array([ 9899241.2366759])

# %% [markdown]
# with transformation

# %%
y, X = dmatrices('dgross ~ log_budget + thriller + comedy + drama + docmentary', data=data, return_type='dataframe')

# %%
model = linear_model.LinearRegression()
model.fit(X, y)
model.score(X, y)
# Out:
# 0.28613345062507911

# %%
y, X = dmatrices('log_gross ~ log_budget + thriller + comedy + drama + docmentary', data=data, return_type='dataframe')

# %%
model = linear_model.LinearRegression()
model.fit(X, y)
model.score(X, y)
# Out:
# 0.19252973814792607

# %% [markdown]
# Lasso / L1 regression

# %%
lasso = linear_model.LassoCV(cv = 15, copy_X = True, normalize = True).fit(X, y)
# Out:
# /Users/kpully/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:1051: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model = linear_model.lasso_path(X, y)

# %%
scores = cross_validation.cross_val_score(lasso, X, y)
scores
# Out:
# /Users/kpully/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:1051: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kpully/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:1051: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/kpully/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:1051: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([-1.12460142, -0.01937285, -0.03488379])

# %% [markdown]
# Ridge / L2 Regression

# %%
clf = linear_model.Ridge (alpha = .5)
print clf.fit(X, y)
print clf.coef_
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# [[ 0.          1.10578368]]

# %%
results = smf.ols(formula="dgross ~ drama + thriller + comedy", data=data).fit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-221-3e773bb55ae0> in <module>()
# ----> 1 results = smf.ols(formula="dgross ~ drama + thriller + comedy", data=data).fit()
#
# AttributeError: 'module' object has no attribute 'ols'

# %% [markdown]
# cross-validation

# %%
x_train, x_test, y_train, y_test = cv.train_test_split(X,y,test_size=0.333,random_state=1234)

# %%
model = linear_model.LinearRegression().fit(x_train, y_train)

# %%
metrics.mean_squared_error(y_train,model.predict(x_train))
# Out:
# 5239516544574071.0

# %%
print model.score(x_train, y_train) #r-squared / coefficient of determination
metrics.mean_squared_error(y_test,model.predict(x_test))
# Out:
# 0.322802116628
# 4632281269974771.0

# %%
kf = KFold(52, n_folds=2)

# %%
for train_index, test_index in kf:
    #X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    #y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    ## Fit on Train! 
    clf2 = LinearRegression().fit(X.iloc[train_index], y.iloc[train_index])
    # Score on Test! 
    print clf2.coef_, metrics.mean_squared_error(y.iloc[test_index], clf2.predict(X.iloc[test_index]))
# Out:
# [[ 0.         -5.25409352]] 2.74141853905e+17
# [[ 0.          1.88379456]] 1.95152858783e+16
